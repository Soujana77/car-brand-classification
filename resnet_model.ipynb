# %%
# ========== shared params (must match VGG16) ==========
train_path = r"D:\car_brand_classification\dataset"   # your dataset path
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS_INITIAL = 20      # initial frozen training
EPOCHS_TOTAL = 25        # total after fine-tuning (so fine-tune for 5)
LR_BASE = 1e-4
LR_FINETUNE = 1e-5
CLASS_MODE = 'categorical'
